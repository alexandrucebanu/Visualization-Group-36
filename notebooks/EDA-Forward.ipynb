# %% [markdown]
# <h1 style="font-size:19px;color:#1563AF;font-weight:600">Exploratory Data Analysis | Forward Players</h1>

# %% [markdown]
# <p style="font-size:16px">JBI100 Visualization | Dana Mirafzal | November 2023</p>

# %% [markdown]
# ---

# %%
##  Imports  ##
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Config
DATADIR="data/"

# %%
## Loading the data files

areas  = ["shooting","possession","playingtime","passing","misc"];
frames = []

counter=0
for area in areas:
    fileName = "player_"+area+".csv"
    frame    =  pd.read_csv(DATADIR+fileName)
    frames.append(frame)

# %%
## Merging all frames into a single one

df=frames[0]
for i in range(1,len(frames)):
    df=pd.merge(df,frames[i])

# %%
## Filtering the players to only get the ones who play in the forward position
df=df[df['position']=="FW"]

# %%
df
# Out:
#                     player position     team     age  birth_year  minutes_90s  \
# 4     Abderrazak Hamdallah       FW  Morocco  32-001        1990          0.8
# 5    Abdessamad Ezzalzouli       FW  Morocco  21-001        2001          1.0
# 7    Abdul Fatawu Issahaku       FW    Ghana  18-285        2004          0.0
# 19         Ahmed Alaaeldin       FW    Qatar  29-321        1993          0.1
# 22              Akram Afif       FW    Qatar  26-030        1996          3.0
# ..                     ...      ...      ...     ...         ...          ...
# 662      Youssef En-Nesyri       FW  Morocco  25-200        1997          6.0
# 666      Youssoufa Moukoko       FW  Germany  18-028        2004          0.0
# 668              Yuki Soma       FW    Japan  25-296        1997          0.9
# 671      Zakaria Aboukhlal       FW  Morocco  22-303        2000          0.9
# 672          Álvaro Morata       FW    Spain  30-056        1992          2.1
#
#      goals  shots  shots_on_target  shots_on_target_pct  ...  crosses  \
# 4        0      2                1                 50.0  ...        0
# 5        0      1                0                  0.0  ...        1
# 7        0      0                0                  NaN  ...        0
# 19       0      0                0                  NaN  ...        0
# 22       0      2                0                  0.0  ...       13
# ..     ...    ...              ...                  ...  ...      ...
# 662      2      9                3                 33.3  ...        0
# 666      0      0                0                  NaN  ...        1
# 668      0      3                0                  0.0  ...        6
# 671      1      3                2                 66.7  ...        1
# 672      3      8                5                 62.5  ...        0
#
#      interceptions  tackles_won  pens_won  pens_conceded  own_goals  \
# 4                0            0       0.0            0.0          0
# 5                0            2       0.0            0.0          0
# 7                0            0       0.0            0.0          0
# 19               0            0       0.0            0.0          0
# 22               0            0       0.0            0.0          0
# ..             ...          ...       ...            ...        ...
# 662              1            2       0.0            0.0          0
# 666              0            0       0.0            0.0          0
# 668              0            0       0.0            0.0          0
# 671              1            1       0.0            0.0          0
# 672              0            1       0.0            0.0          0
#
#      ball_recoveries  aerials_won  aerials_lost  aerials_won_pct
# 4                4.0          1.0           7.0             12.5
# 5                4.0          1.0           2.0             33.3
# 7                0.0          0.0           0.0              NaN
# 19               0.0          0.0           0.0              NaN
# 22              14.0          1.0           1.0             50.0
# ..               ...          ...           ...              ...
# 662             13.0         21.0          14.0             60.0
# 666              1.0          0.0           0.0              NaN
# 668              2.0          0.0           0.0              NaN
# 671              3.0          2.0           0.0            100.0
# 672              2.0          1.0           0.0            100.0
#
# [185 rows x 97 columns]

# %%
def getAgeYears(ageString):
    return int(ageString.split('-')[0])
df['age']=(df['age']).map(getAgeYears)

# %%
df
# Out:
#                     player position     team  age  birth_year  minutes_90s  \
# 4     Abderrazak Hamdallah       FW  Morocco   32        1990          0.8
# 5    Abdessamad Ezzalzouli       FW  Morocco   21        2001          1.0
# 7    Abdul Fatawu Issahaku       FW    Ghana   18        2004          0.0
# 19         Ahmed Alaaeldin       FW    Qatar   29        1993          0.1
# 22              Akram Afif       FW    Qatar   26        1996          3.0
# ..                     ...      ...      ...  ...         ...          ...
# 662      Youssef En-Nesyri       FW  Morocco   25        1997          6.0
# 666      Youssoufa Moukoko       FW  Germany   18        2004          0.0
# 668              Yuki Soma       FW    Japan   25        1997          0.9
# 671      Zakaria Aboukhlal       FW  Morocco   22        2000          0.9
# 672          Álvaro Morata       FW    Spain   30        1992          2.1
#
#      goals  shots  shots_on_target  shots_on_target_pct  ...  crosses  \
# 4        0      2                1                 50.0  ...        0
# 5        0      1                0                  0.0  ...        1
# 7        0      0                0                  NaN  ...        0
# 19       0      0                0                  NaN  ...        0
# 22       0      2                0                  0.0  ...       13
# ..     ...    ...              ...                  ...  ...      ...
# 662      2      9                3                 33.3  ...        0
# 666      0      0                0                  NaN  ...        1
# 668      0      3                0                  0.0  ...        6
# 671      1      3                2                 66.7  ...        1
# 672      3      8                5                 62.5  ...        0
#
#      interceptions  tackles_won  pens_won  pens_conceded  own_goals  \
# 4                0            0       0.0            0.0          0
# 5                0            2       0.0            0.0          0
# 7                0            0       0.0            0.0          0
# 19               0            0       0.0            0.0          0
# 22               0            0       0.0            0.0          0
# ..             ...          ...       ...            ...        ...
# 662              1            2       0.0            0.0          0
# 666              0            0       0.0            0.0          0
# 668              0            0       0.0            0.0          0
# 671              1            1       0.0            0.0          0
# 672              0            1       0.0            0.0          0
#
#      ball_recoveries  aerials_won  aerials_lost  aerials_won_pct
# 4                4.0          1.0           7.0             12.5
# 5                4.0          1.0           2.0             33.3
# 7                0.0          0.0           0.0              NaN
# 19               0.0          0.0           0.0              NaN
# 22              14.0          1.0           1.0             50.0
# ..               ...          ...           ...              ...
# 662             13.0         21.0          14.0             60.0
# 666              1.0          0.0           0.0              NaN
# 668              2.0          0.0           0.0              NaN
# 671              3.0          2.0           0.0            100.0
# 672              2.0          1.0           0.0            100.0
#
# [185 rows x 97 columns]

# %%
df.aggregate('mean')
# Out:
# C:\Users\98903\AppData\Local\Temp\ipykernel_8692\3694068112.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.aggregate('mean')
# age                  26.389189
# birth_year         1995.562162
# minutes_90s           1.815135
# goals                 0.621622
# shots                 3.924324
#                       ...
# own_goals             0.000000
# ball_recoveries       6.377049
# aerials_won           2.409836
# aerials_lost          3.650273
# aerials_won_pct      35.373913
# Length: 94, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# <h4 style="font-size:17px;font-weight:600;color:#158B6A">Age of Players</h4>

# %% [markdown]
# **Distribution of age among forward players**

# %%
df['age'].hist()
# Out:
# <AxesSubplot: >
